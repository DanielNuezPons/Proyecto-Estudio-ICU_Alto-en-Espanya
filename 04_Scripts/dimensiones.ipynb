# %%
import pandas as pd

data = [
    (1, "Andalucía"),
    (2, "Aragón"),
    (3, "Asturias"),
    (4, "Illes Balears"),
    (5, "Canarias"),
    (6, "Cantabria"),
    (7, "Castilla-La Mancha"),
    (8, "Castilla y León"),
    (9, "Cataluña"),
    (10, "Comunitat Valenciana"),
    (11, "Extremadura"),
    (12, "Galicia"),
    (13, "La Rioja"),
    (14, "Madrid"),
    (15, "Murcia"),
    (16, "Navarra"),
    (17, "País Vasco"),
    (18, "Ceuta"),
    (19, "Melilla"),
]

dim_ccaa = pd.DataFrame(data, columns=["CCAA_id", "CCAA_std"])
dim_ccaa
# Out:
#     CCAA_id              CCAA_std
# 0         1             Andalucía
# 1         2                Aragón
# 2         3              Asturias
# 3         4         Illes Balears
# 4         5              Canarias
# 5         6             Cantabria
# 6         7    Castilla-La Mancha
# 7         8       Castilla y León
# 8         9              Cataluña
# 9        10  Comunitat Valenciana
# 10       11           Extremadura
# 11       12               Galicia
# 12       13              La Rioja
# 13       14                Madrid
# 14       15                Murcia
# 15       16               Navarra
# 16       17            País Vasco
# 17       18                 Ceuta
# 18       19               Melilla

# %%
from pathlib import Path

OUT = Path("../../Data_clean")
OUT.mkdir(exist_ok=True)

dim_ccaa.to_csv(OUT / "Dim_CCAA.csv", index=False)

# %%
type(dim_ccaa)
# Out:
# pandas.core.frame.DataFrame

# %%
from pathlib import Path

OUT = Path("../../Data_clean").resolve()
print("Guardando en:", OUT)
OUT.mkdir(parents=True, exist_ok=True)

file_path = OUT / "Dim_CCAA.csv"
dim_ccaa.to_csv(file_path, index=False, encoding="utf-8")
print("✅ Guardado:", file_path)
print("Existe?:", file_path.exists())
# Out:
# Guardando en: C:\Users\nuez_\Data_clean
# ✅ Guardado: C:\Users\nuez_\Data_clean\Dim_CCAA.csv
# Existe?: True

# %%
sorted([p.name for p in OUT.iterdir()])
# Out:
# ['Dim_CCAA.csv']

# %%
from pathlib import Path

p1 = Path(r"C:\Users\nuez_\Data_clean\Dim_CCAA.csv")
print("Existe en C:\\Users\\nuez_\\Data_clean ?", p1.exists(), p1)

p2 = Path(r"C:\Users\nuez_\Desktop\Proyecto ENSE\Data_clean\Dim_CCAA.csv")
print("Existe en Proyecto ENSE\\Data_clean ?", p2.exists(), p2)
# Out:
# Existe en C:\Users\nuez_\Data_clean ? True C:\Users\nuez_\Data_clean\Dim_CCAA.csv
# Existe en Proyecto ENSE\Data_clean ? False C:\Users\nuez_\Desktop\Proyecto ENSE\Data_clean\Dim_CCAA.csv

# %%
from pathlib import Path

OUT = Path(r"C:\Users\nuez_\Desktop\Proyecto ENSE\Data_clean")

OUT.mkdir(parents=True, exist_ok=True)

file_path = OUT / "Dim_CCAA.csv"
dim_ccaa.to_csv(file_path, index=False, encoding="utf-8")

print("✅ Guardado en:", file_path)
print("Existe?:", file_path.exists())
# Out:
# ✅ Guardado en: C:\Users\nuez_\Desktop\Proyecto ENSE\Data_clean\Dim_CCAA.csv
# Existe?: True
